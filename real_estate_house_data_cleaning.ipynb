# %% [markdown]
# # Data Science Regression Project: Predicting Apartment Prices in Germany

# %%
from os import listdir
import pandas as pd
import re

# %%
# finding json files in givin path 
def find_csv_filenames(path_to_dir, suffix=".csv" ):
    filenames = listdir(path_to_dir)
    return [filename for filename in filenames if filename.endswith(suffix)]

# %%
def concatenate_path_csv_file():
    path_with_csv_files = []
    for csv_file in csv_files:
        path_with_csv_files.append(path+csv_file)
    return path_with_csv_files

# %% [markdown]
# ## Data Load: Load germany apartment data, to see features

# %%
path = r"./house_data/"
csv_files = find_csv_filenames(path)
df = pd.concat(map(pd.read_csv, concatenate_path_csv_file()), ignore_index=True)

# %%
df.head(5)
# Out:
#   sales_price livable_surface      land  number_of_rooms  \
# 0    548,000€           123m²     894m²                3
# 1     64,000€            76m²     612m²                4
# 2    485,000€           180m²  71,600m²                6
# 3     47,000€            96m²     117m²                4
# 4    595,000€           389m²   1,230m²               15
#
#                                  location
# 0                            -Merzkirchen
# 1                    Danneilweg-Salzwedel
# 2  ImHainbruch16,54317Gusterath-Gusterath
# 3               IllingerStraße-Heusweiler
# 4                                   -Zerf

# %%
# we have 1116 houses and 5 features
df.shape
# Out:
# (1116, 5)

# %%
# sales_price is the dependent feature, the rest are independet. We try to predict the sales_price
df.columns
# Out:
# Index(['sales_price', 'livable_surface', 'land', 'number_of_rooms',
#        'location'],
#       dtype='object')

# %%
# unique method is used to get an overview of unique elements in specific index.
df['location'].unique()
# Out:
# array(['-Merzkirchen', 'Danneilweg-Salzwedel',
#        'ImHainbruch16,54317Gusterath-Gusterath',
#        'IllingerStraße-Heusweiler', '-Zerf', 'ZumWaldhaus-Riedenburg',
#        'HöwischerStraße-Arendsee', 'Ernteweg-Kulmbach', '-Rittersdorf',
#        '-Retterath', '-Trier', '-Wadern', '-Perl', '-Saarbrücken',
#        'Riedhofstraße-Weißenhorn', 'NadorsterStraße-Oldenburg',
#        '-Minderlittgen', '-Hentern', '-Mettlach', '-Alsdorf',
#        '-Wincheringen', 'Hindenburgstraße-Herzberg', '-Langsur',
#        'Kirchenstrasse-Perl', '-Bollendorf', '-Kaiserslautern',
#        '-Neuerburg', 'Dorfstraße-Gera', '-Speicher',
#        'MerzigTheexactadressisnotindicated',
#        'PerlTheexactadressisnotindicated', '-Waxweiler', '-Großrosseln',
#        '-Losheim', '-Übereisenbach', 'Herzogstraße-Duisburg', '-Malberg',
#        'Hauptsrasse-Kleinblittersdorf', '-Saarlouis', '-Taben-Rodt',
#        '-Riveris', '-Waldweiler', 'Grasberg-BadNeustadt', '-Saarburg',
#        '-Schillingen', '-Waldrach', 'AmDreschplatz-Linsburg', '-Schleich',
#        '-Mandern', '-Heddert', '-Serrig',
#        'Ostpreußenstraße-Gelsenkirchen', '-Kell', '-Kastel-Staadt',
#        '-Detzem', '-Klüsserath', '-Hinzenburg', '-Freudenburg',
#        'Herderstraße-Titz', '-Spangdahlem', '-Hütterscheid', '-Herforst',
#        '-Manderscheid', '-Neunkirchen', '-Hermeskeil', '-St.Ingbert',
#        '-Beckingen', '-Fell', '-Heusweiler', '-Kesten', '-Saarwellingen',
#        '-Jünkerath', '-Nauheim', '-Höxter', '-Merzalben', '-Hillesheim',
#        '-Birnbach', '-Merzig', '-Pelm', '-Zell', '-Nalbach', '-Trassem',
#        '-Ürzig', '-Burg', '-Dillingen', '-Kirf', '-Jucken', '-Lebach',
#        '-Schalkenmehren', '-Thalfang', '-Homburg', '-Bous',
#        '35,PreisterStrasse-Speicher', '-Uersfeld', '-Dieburg',
#        '-Darscheid', '-Arzfeld', '-Illingen', '-Düren', '-Utscheid',
#        '-Dorsel', '-Völklingen', '-Marpingen', '-Theisbergstegen',
#        '-Mendig', '-Überherrn', '-Peffingen', '-Daun', '-Wallerfangen',
#        '-Nittel', '-Bernkastel-Kues', '-Sulzbach', '-Rodershausen',
#        '-Wolsfeld', '-Urschmitt', '-Schwalbach', '-Pluwig', '-Lieser',
#        '-Kröv', '-Leiwen', '-Ayl', '-Riegelsberg', '-Hosten', '-Rühen',
#        '-Sellerich', '-Blieskastel', '-Großlittgen',
#        '-Bruchmühlbach-Miesau', '-Nohfelden', '-Lügde', '-Schmelz',
#        '-Eppelborn', '-Kirchweiler', '-Zweibrücken', '-Meinersen',
#        '-Hetzerath', '-Altscheid', '-Wadgassen', '-Lambertsberg',
#        '-Nonnweiler', '-Zemmer', '-Körperich', '-Echternacherbrück',
#        '-Gillenfeld', '-Longuich', '-Quierschied', '-Obernholz', '-Thomm',
#        '-Kyllburg', '-Geichlingen', '-Idar-Oberstein', '-BadSobernheim',
#        '-Orenhofen', 'Hölderlinstraße-Gotha', '-Schieder-Schwalenberg',
#        '-Bexbach', '-Letschin', 'AlteTriererStraße-Binsfeld',
#        '-Saterland', '-Schweich', '-Neichen', '-Wustermark', '-Ernzen',
#        '-Pfinztal', '-Trierweiler', 'Bernanosweg-Köln', '-Ottweiler',
#        '-Dahlem', '-Balesfeld', '-Erlensee', 'Drosselstraße-Ottobrunn',
#        '-Wandlitz', '-Hankensbüttel', 'GronauerStraße-Oberstenfeld',
#        '-Holzminden', '-Wittlich', '-Riedstadt', '-Merchweiler',
#        'Schulstraße-Forbach', 'Kirchstraße-Merenberg', '-Echzell',
#        '-Schiffweiler', '-Krottelbach', '-Gerolstein',
#        'Tannenbrunnenstraße-Sachsenheim', 'Weiherstr.-Daleiden',
#        '-Welschbillig', '-Wilsecker', 'Burgstrasse-Koxhausen',
#        'AnderAllee-Neuburg', '-Irsch', '-Binsfeld',
#        'Boerskamp-Wallenhorst', '-Kirkel', '-Daleiden', '-Herbstein',
#        '-Landstuhl', '-Blankenheim', 'AmBerge-Wolfen', '-Simmerath',
#        '-Schwarzach', '-Ruhmannsfelden', '-Krautscheid', '-St.Wendel',
#        '-Börfink', 'Bahnhofstraße-Bach', 'GroßerMarkt-Saarlouis',
#        'Ulmenstraße15-Saarlouis', 'NalbachTheexactadressisnotindicated',
#        '-Kerpen', '-Schmitten', '-Bettingen', '-Metterich',
#        'Hubertusstraße-Kaarst', '-Gielert', '-Rabenau', '-Wallersheim',
#        '-Hinzert-Pölert', '-Schleid', 'Oemberg-Arnsberg', '-Igel',
#        '-Kleinblittersdorf', '-Wölfersheim', 'Bachtalstraße-Schwalbach',
#        '-54636Wissmannsdorf', '-Bitburg',
#        'SaarlouisTheexactadressisnotindicated', 'AmGoldberge-Beverungen',
#        '-Frankfurt', '-Dudeldorf', '-BadEndbach', '-Roth', '-Wiltingen',
#        '-Üxheim', 'Wacholderweg-Niederkrüchten',
#        'RoermonderStraße-Schwalmtal', '-Weiskirchen',
#        'OrtranderStr.-Merzdorf', 'ArtlenburgerLandstraße-Adendorf',
#        'Möwenweg-Achim', 'Obermoselstrasse-Palzem', '-BiersdorfamSee',
#        'Kastanienstraße-Köthen', 'WartenburgerStraße-Kemberg',
#        'Kurzenbergstraße-Riegelsberg', 'Mühlenbach-Altena',
#        'FrauenkronerWeg-Hellenthal', 'AmOsterbach-Oberried',
#        'Schneidergasse-Schönenberg-Kübelberg',
#        'GörlitzerStraße-Rothenburg', 'OrtranderStraße-Lampertswalde',
#        'UntenamSteinwald-Neunkirchen', 'Kirschweg-Grimma',
#        'Unterlandstraße-Neuhaus', 'Fasanenstraße-Auerbach',
#        'SaargemünderStraße-Saarbrücken', 'HochheimerStraße-Hattersheim',
#        'Dondertstraße-Kevelaer', 'Eberhardstraße-Remscheid',
#        'Bahnhofstraße-Kyllburg', 'Klingenbergstraße-Oldenburg',
#        'Schneppel-Delligsen', 'Bergstraße-Leinach', 'Eckstumpf-Solingen',
#        'Asamstraße-Friedberg', 'ImBöge-Peine', 'Michaelstraße-Höxter',
#        'Hammerleite-Hirschbach', 'Schloßstraße-Sien',
#        'Paschenbergstraße-Herten', 'HummelsbüttelerLandstr.-Hamburg',
#        'Festeburgstraße-Neuhaus', 'Hans-Tönies-Ring-Lüneburg',
#        'GroßeKummstraße-Sassnitz', 'Gobbin-Lancken-Granitz',
#        'Hauptstraße-Bubach', 'Beesedau-Könnern', 'Südbockhorn-Salzwedel',
#        'Rockenthin-Salzwedel', 'Bodestraße-Benneckenstein',
#        'Lerchenweg-Homberg', 'Karlstraße-Herten', 'Klüsenerstraße-Bochum',
#        'AachenerStraße-Eschweiler', 'Groppenbachstraße-Castrop-Rauxel',
#        'Neukrapohl-Mönchengladbach', 'LangeStraße-Lahstedt',
#        'ObereGärten-Ludwigsstadt', 'Hohentreswitz-Pfreimd',
#        'Schäferstraße-Ingolstadt', 'Hainholzweg-Hamburg',
#        'Vogesenstraße-Baden-Baden', 'WormserStraße-Maxdorf',
#        '-Lützkampen', 'Lilienstraße-Könnern', 'BerlinerPromenade-Burg',
#        'EilenburgerStraße-Laußig', 'TrossinerStraße-Süptitz',
#        'Parthenstraße-Grimma', 'AmTeichdamm-Colditz',
#        'Hauptstraße-Beilrode', 'AltenhainerStraße-Hofheim',
#        'ZurLandsburg-Schwalmstadt', '-Wiersdorf',
#        'AmHolmbach-Frielendorf', 'Vitalisstraße-Köln',
#        'Mosenbergstraße-Köln', 'KatzwangerStraße-Wendelstein',
#        'Herrenholzstraße-Neustadt', 'Vigölensoll-Neustadt',
#        'Forstweg-Wyk', 'Heinrich-Lohse-Straße-Quickborn',
#        'Op`nWischhoff-Wiemersdorf', 'AugsburgerWeg-Schwesing',
#        'Schönblick-BadRappenau', 'Luhnhofweg-Lahr',
#        'Kirchenäcker-Blaubeuren', 'Fischgrubenweg-Rottenacker',
#        'Falkenweg-Dettenheim', 'Maiwaldstraße-Krottelbach',
#        'Freiherr-v.-Gagern-Straße-Kleinniedesheim', 'Stiftstraße-Parchim',
#        'ZumLangenHofe-Schlagsdorf', 'Schäferkamp-Neustadt-Glewe',
#        'ImWinkel-BadMünder', 'DahnenTheexactadressisnotindicated',
#        'Hiltensberg-Sulzberg', 'AmZiegenberg-Oberaula', '-Aach',
#        'SchönbacherDorfstraße-Kamenz', 'Kegelbahn-Gladenbach',
#        'AmWasser-Cornberg', 'Minnacker-Biedenkopf',
#        'Sudetenstraße-Maintal', 'Ruhrstraße-Hanau', 'Elsaßstraße-Essen',
#        'Waldesruh-Schalksmühle', 'Marquard-v.-Grumbach-Str.-Rothenfels',
#        'VillingerStraße-Riedlingen', 'Schauinsland-Igel',
#        'Hinterstraße-Treplin', 'Burgstraße-Loburg',
#        'AmMühlwald-St.Ingbert', 'Kehreinstraße-Frankfurt',
#        'LangeGasse-Altenstadt', 'Quergartenweg-Hanau', '-Stadtkyll',
#        'Birkenstraße-Kulmbach', 'Rosengasse-Pegnitz',
#        'Ölbergstraße-Unterpleichfeld', 'AnderKirche-Bismark',
#        'Petristraße-Seehausen', 'BörgitzerDorfstraße-Stendal',
#        'Pappelallee-Stendal', 'RoteGasse-Meißen',
#        'Feldstraße-Markersdorf', 'AndenWeiden-Detmold',
#        'Bahnhofstrasse6-Rascheid', 'IngelheimerStraße-Frankfurt',
#        'Wohlfahrtstraße-Bochum', 'HasselerStraße-Gelsenkirchen',
#        'MarienbaumerStraße-Xanten', 'Dorffeld-Senden',
#        'Pfarrfeldstraße-Gerzen', 'WeißeRiete-Schüttorf',
#        'Tulpenstraße-Erding', 'Dohlenweg-Geisenhausen',
#        'LuxembourgerAllee62-Wincheringen', 'Blumenstraße-Neuching',
#        'Kaimstraße-Schelklingen', 'Eschenweg-Pforzheim',
#        'ObereBurg-Saalfeld', 'Röhrenweg-Rudolstadt',
#        'Anger-Pferdingsleben', 'AnderBurgaue-Leipzig',
#        'AnderKirche-Großpösna', 'Jägerhausstraße-Herborn',
#        'AmHopfenberg-Reinhardshagen', 'Brühlweg17-Perl',
#        'Pastorskamp-Nottuln', 'Brüder-Grimm-Weg-Holzminden',
#        'AmKreuzweg-Münnerstadt', 'Schanzstraße-Teublitz',
#        'WürzburgerStraße-Höchberg', 'Krenmoosstraße-Karlsfeld',
#        'Puchtastraße-Cadolzburg', 'Daheimstraße-Querfurt',
#        'Neustr.-Freudenburg', 'ImErlich-Darmstadt',
#        'Helfensteinstraße-Kassel', 'Tangenberg-Wilsum',
#        'NordhalbenerStraße-Steinwiesen', 'AmKlingenberg-Sulzdorf',
#        'WildensorgerHauptstraße-Bamberg', 'Weihergasse-Allersberg',
#        'Falkenstein-Donnersdorf', 'Raiffeisenstraße-Arnstein',
#        'Chattenstraße-Mainz', 'Eichendorffweg-Triberg',
#        'WaldheimerStraße-Waldheim', 'Reinholdstraße-Limbach-Oberfrohna',
#        'St.IngberterStraße-Mandelbachtal', 'InderEcke-Borken',
#        'AmNauhauserWeg-Saarbrücken', 'Apolloniaweg-Kürten',
#        'ImBeisen-Marl', 'Eintrachtstraße-Erftstadt', 'Gottsberg-Zülpich',
#        'StübbenerStraße-Solingen', 'Trift-Winsen', 'Querstraße-Nienhagen',
#        'SoltauerStraße-Bergen', 'Göppelberg-Ziemetshausen',
#        'Richard-Wagner-Straße-Weißenhorn', 'Bahnhofstraße-BadSachsa',
#        'Wiesengrund-Borgstedt', 'Bricciusstraße-Rottenburg',
#        'BeimPreußischen-Rottenburg', 'Hähnkamp-Stafstedt',
#        'Fasanenweg-Elchingen', 'Lindenstraße-Schraplau',
#        'Wallstraße-Marl', 'HusenerStraße-Lübbecke', 'Kiesweg-Oberhausen',
#        'Nielitz-Düvier', 'Levkojenweg-Mannheim',
#        'Carl-Bosch-Ring-Frankenthal', 'Gartenstraße-Essenbach',
#        'Rosengarten-Neuendeich', 'LeipzigerStraße-Meißen',
#        'Bergstraße-Neustadt', 'Pfarrberg-Penig',
#        'Rimlingerstraße-Losheim', 'ZumPavillon-Wadern',
#        'Kirchenweg-Wadern', 'AmEbert-Lebach', 'Mühlenweg-Leverkusen',
#        'Lautawerkstraße-Grevenbroich',
#        'MackenbrucherStraße-Oerlinghausen', 'Ellerbruchstraße-Dorsten',
#        'Schmillenburg-BergischGladbach', 'Narzissenstraße-Dortmund',
#        'Rotgerweg-Dortmund', 'AltenroderStraße-Dassel',
#        'AltMöhlenwarf-Weener', 'WittmunderStraße-Jever',
#        'Gannerkamp-Visselhövede', 'Kantstraße-Papenburg',
#        'SeulbergerStraße-BadHomburg', 'Lindenstraße-Morschen',
#        'Wiesenstraße-Vohenstrauß', 'Brunnenstraße-Baldham',
#        'Ahornweg-Oberasbach', 'Gundekarstraße-Roßtal',
#        'Hopfenstraße-Waldsassen', 'Münchtalstraße-Haschbach',
#        'Feldstraße-BadKleinen', '1Kirchenberg-Wincheringen',
#        'GadebuscherChaussee-Holdorf', 'EichtersheimerStraße-Mühlhausen',
#        'Vogelbergweg-Gaggenau', 'BruhnskoppelerWeg-Malente',
#        'Holitzberg-Hamburg', 'Golterstraße-Köngen',
#        'Friedenstraße-Genthin', 'AmJämmchen-Moritzburg',
#        'Kirchenstraße-Schmelz', 'ZumBassin-Mettlach',
#        'Herbert-Müller-Straße-Schweinfurt', 'Wiesenweg-Steinwiesen',
#        'SonthofenerStraße-Burgberg', 'Pyras-Thalmässing',
#        'Panoramastraße-Ummendorf', 'Geigerstraße-Gräfelfing',
#        'Faganastraße-München', 'Braunsberg-BergischGladbach', '-Konz',
#        'Flurweg-Oberreidenbach', 'W.-Schnackenberg-Weg-München',
#        'Erich-Ollenhauer-Straße-Dachau', 'Stümpflingstraße-Grünwald',
#        'AmLindenfeld-Frankfurt', 'Schmiedwiese-Reitmehring',
#        'Thebäerstraße-Trier', '-Ralingen',
#        'August-Bebel-Platz-Teutschenthal', 'AnderLinde-Gornau',
#        '-Rommersheim', '-Wellen', '-Newel',
#        'Johann-Kierspel-Straße-Overath', 'StockheimerStraße-Versmold',
#        'Vorderhügel-Zella-Mehlis', 'Dunzweilerstraße-Waldmohr',
#        'Sommerseite-Lampertswalde', '10-12-Roth', 'Enzweg-Holsthum',
#        'Hübelstraße-Nußbach', 'Friedrich-Franz-Straße-Dömitz',
#        'Friedensstraße-Könnern', 'LindenbergerStraße-Oppach',
#        'Gasse-Malsfeld', 'Alsfassenerstraße-St.Wendel',
#        'Fluraustraße-Neuwied', 'Landstraße-Linnich',
#        'KornharpenerStraße-Bochum', 'DortmunderStraße-Recklinghausen',
#        'ImSchönenFeld-BergischGladbach', 'AmKülfhofe-Duingen',
#        'AmWingert-Düren', 'Mozartstraße-Saterland',
#        'Georg-Janssen-Straße-Schortens', 'Fritz-Reuter-Straße-HohenPritz',
#        'Industriestraße-Rastatt', 'Blumbergstraße-Teningen',
#        'LandstuhlerStraße-Obernheim', 'Bahnhofstraße-Dähre',
#        'AmKirschberg-Dingelstedt', 'KleineAugasse-Meerane',
#        'AußenerStraße-Beckingen', 'Elchdamm-Berlin', 'Ludgeristraße-Heek',
#        'Heinrich-Lübke-Straße-Sundern', '-Burbach', 'Oberwiese-Waltrop',
#        'Ramsberg-Schöppingen', 'ZumFellengarten-Haunetal',
#        'Ulmenstraße-Rechtsupweg', 'Dechant-Bluel-Straße-Giesen',
#        'Erlenstraße-Gochsheim', 'Lärchenstraße-Gochsheim',
#        'GodemserWeg-Spornitz', 'TechentinerStraße-Ludwigslust',
#        'ImEck-Tarnow', 'StraßedesFriedens-Vierlinden',
#        'EppendorferStraße-Grünhainichen', 'ZurJahnaquelle-Döbeln',
#        'Bahnhofstraße-Oelsnitz', 'Habichtswaldstraße-Borken',
#        'Höhenweg-Herten', 'Bachweg-Hünxe', 'Rohstraße-Hamminkeln',
#        'Anderten-Heemsen', 'Pastorenweg-Bremen', 'TriererStraße-Nürnberg',
#        'Ostring-Riedstadt', 'AmHasenbach-Mügeln',
#        'Bergstraße-Steffenberg', 'UelzenerStraße-Eschede',
#        'ZumWiesengrund-Niederwambach', 'GönnersdorferStraße-Jünkerath',
#        'Holbeinstraße-BadKreuznach', 'Moretzstraße-Weilburg',
#        'WormserStraße-Gernsheim', 'OttendorferStraße-Laußnitz',
#        'Rundweg-Borken', 'BüttenbergerStraße-Ennepetal',
#        'ScharpenbergerStraße-Ennepetal', 'ImDorfe-Kaulsdorf',
#        'LaasenerStraße-Probstzella', 'Neustadt-BadLobenstein',
#        'Theodor-Fliedner-Straße-Gelsenkirchen', 'Kröngensgasse-Düren',
#        'ZumKiefernberg-Cunewalde', 'Heidestraße-Langenhagen',
#        'ImTal-Nußbaum', 'Bierkellergasse-Reilingen', '-Lahr', '-Minheim',
#        'Castellweg-Wallendorf', 'Steingartenstraße-Dietingen',
#        'AnderNachtweide-Magdeburg', 'Friedhofstraße-Greifenstein',
#        'RotenburgerStraße-Bebra', 'Zeppelinstraße-Rüsselsheim',
#        'ZurBonwiese-Amöneburg', 'Landfurt-Warburg',
#        'Otto-Hahn-Weg-Lübbecke', 'Bergdorfstraße-Springe',
#        'St.-Rochus-Straße-Würzburg', 'Landstraße-Ühlingen-Birkendorf',
#        'Matthias-Grünewald-Ring-Schweinfurt', 'Berggrenze-Hettstedt',
#        'Wallgasse-Rochlitz', 'Schillerstraße-Neunkirchen',
#        'SitterswalderStraße-Kleinblittersdorf', 'Ringstraße-Saarbrücken',
#        'Sulzbachtalstraße-Saarbrücken', 'Krankenhausstaße-Hürth',
#        'Damaschkeweg-Wesel', 'Jungfernbruch-Hagen', 'AmAnwer-Dorsten',
#        'ImWillstein-BadBerleburg', 'AhlshäuserMenganger-Einbeck',
#        'ImDorfe-Einbeck', 'Danielstraße-Braunlage', 'LangeStraße-Brake',
#        'Sägemüllerstraße-Clausthal-Zellerfeld', 'Sportplatzweg-Brachttal',
#        'Ringstraße-Hasselroth', 'NiedergründauerStraße-Gründau',
#        'Reinting-Hohenpolding', 'AmSandberg-Seedorf',
#        'NordhusumerStraße-Husum', 'Suckweg-Hamburg',
#        'Brummerskamp-Hamburg', 'BüttjebüllerKirchenweg-Bordelum',
#        'Sybrandts-Rastedt-Weg-Apen', 'StrombergerStraße-Daxweiler',
#        'Metzerstraße-Tholey', 'Dürerstraße-Wildeck',
#        'Hermann-Wolf-Straße-Freital', 'Bergsiedlung-Dresden',
#        'Hauptstraße-Käbschütztal', 'Steinhauerstraße-Springe',
#        'HintermRehbühl-Weiden', 'Hans-Paulus-Straße-Bubenreuth',
#        'Schwemberg-Warburg', 'Brandtstraße-Berlin', 'Osianderweg-Berlin',
#        'Schweiäckerstraße-Hauenstein', 'St.-Nazarius-Straße-Mommenheim',
#        'Webergasse-Frohburg', 'Paul-Schneider-Straße-Marl',
#        'Justus-Kiepe-Straße-Hameln', 'Forsthofstraße-HessischOldendorf',
#        'Haardtstraße-Heßheim', 'Waldstraße-Walkenried',
#        'Lutherstraße-Contwig', 'Fichteraweg-Nordhalben',
#        'Hermann-Löns-Straße-Greiz', 'Salzweg-Greiz',
#        'Carl-Schurz-Straße-Erftstadt', 'AmOhlenbach-Weiterstadt',
#        'Pfarrer-Wichert-Straße-Königswinter', 'Buchenallee-Schkeuditz',
#        'VorderUhlenmühle-BadDriburg', 'Hauptstraße-Tüttleben',
#        'Rennweg-Todtnau', 'Lindenstraße-Parchim',
#        'Stefanstraße-Gevelsberg', 'NehmitzNr.-Groitzsch',
#        'BrockhagenerStraße-Steinhagen', 'AmKatzenstück-Bolanden',
#        '-Kinheim', 'Butterberg-Langenwetzendorf',
#        'FlammersfelderStraße-Asbach', 'Beethovenstraße-Hattersheim',
#        'KelheimerStr.-Langquaid', '-Brauneberg',
#        'Edelmannsgasse-Schillingstedt', 'Winterbachsroth-Saarbrücken',
#        'Bornbrook-Travenhorst', 'ÜberherrnerStraße-Überherrn',
#        'Fichtenhain-Ratingen', 'Eichendorffstraße-Ratingen',
#        'Ebertstraße-Einbeck', 'Dorfweg-Murr', 'AndenEichen-Osloß',
#        'ZweibrückerStraße-Vinningen', 'Grenzweg-Altensteig',
#        'AmHöms-BadHönningen', 'GroßeForststraße-Niederzier',
#        'Kaiserstraße-Titz', 'Rudolfstraße-Lübbecke',
#        'Stoltenmühle-Lübbecke', 'Zaunkönigweg-Dorsten',
#        'Gnadenberg-Eiterfeld', 'Heiligkreuzstraße-Wartmannsroth',
#        'Buchbinderweg-Berlin', 'Horbach-Grafengehaig',
#        'VogtendorferStraße-Guttenberg', 'InderHohrheck-Neroth',
#        'AsemisserAllee-Leopoldshöhe', 'ReckumerHeide-Wildeshausen',
#        'AlteBadstraße-Oberreichenbach', 'ImGassengarten-Plein',
#        'Schubertstraße-Bechhofen', 'Eisenbahnstaße-Aue',
#        'V.-Reuschenberg-Straße-Aldenhoven', 'Wallenburgstraße-Busenberg',
#        'SwinemünderStraße-Hamburg', 'NeumarkterStraße-Osnabrück',
#        'Kuhäckerstraße-Erligheim', 'Eckstraße-Sohren',
#        'Eichenweg-Stromberg', 'SögenlocherWeg-Nieder-Olm',
#        'AmRing-Südharz', 'StendalerStraße-Arneburg',
#        'Hinterstraße-Selmsdorf', 'ImEichgarten-Lebach',
#        'RoterRain-Hauneck', 'Bürgermeister-Brecht-Ring-Lahstedt',
#        'Hermann-Zurlage-Straße-Neubörger', 'Hermann-Gils-Straße-Alfeld',
#        'ImBornerGrund-Mainz', 'Überlauterecken-Lauterecken',
#        'Bornstraße-Gutenacker', 'Theresenstraße-Hagen',
#        'Meisenweg-Geldern', 'Paul-Leo-Straße-Osnabrück',
#        'Hauptstraße-Landstuhl', 'Seestraße-HohenPritz',
#        'Schrootenstraße-Duisburg', 'AmOsthoff-Dülmen',
#        'KönigsbergerStraße-Melle', 'Hauptstraße-Wilhelmsthal',
#        'Schwarzenbergstraße-Wadern', 'Friedenstraße-Oberstenfeld',
#        'Friedhofstraße-Althornbach', '-Holsthum',
#        'Heuchterstraße-Wegberg', '-Graach', 'Wallensteinstraße-Duisburg',
#        'Adolf-Fischer-Straße-Jülich', 'Bayernstraße-Oerlenbach',
#        'AmSchäfersberg-Roßdorf', 'AnderFerndorf-Hilchenbach',
#        'MenzenbergerStraße-BadHonnef', 'Mühlstraße-Krickenbach',
#        'Bockmühlenweg-Selm', 'AmRahmerBach-Duisburg',
#        'KronacherStraße-Steinbach', 'Leisartstraße-Jülich',
#        'Louise-Schröder-Weg-Darmstadt', 'AmBurgtor-BergischGladbach',
#        'Colmblick-Leipzig', 'Ottostraße-Duisburg',
#        'SalzuflerStraße-Lemgo', 'Hafenstraße-Bodenfelde',
#        'Hauptstraße-Hofheim', 'AmAltenBach-Hofheim',
#        'WevelinghoverStraße-Nettetal', 'Schulstraße-Nassau',
#        'KreuzheckerStraße-Lebach', 'LehenHof-Kirchweiler',
#        'AmweißenBerg-Schmitten', 'Heckenweg-Hann.Münden',
#        'SchaufenbergerStraße-Hückelhoven', 'Brüder-Grimm-Straße-Eschborn',
#        'Waldstraße-Schmitten', 'Oberortstraße-Eschborn',
#        'AnderWarnau-Bomlitz', 'ErfenbacherStraße-Kaiserslautern',
#        'Mittelfeld-Dahlenburg', 'Heinrich-Heine-Straße-Groß-Gerau',
#        'Schillerring-Heltersberg', 'AmThümmlitzsee-Grimma',
#        'Venekotenweg-Niederkrüchten', 'WaldenburgerStraße-Gößnitz',
#        'Aktienstraße-Essen', 'Höhnkoppelort-Hamburg', 'Rosengasse-Tettau',
#        'AuerbacherStraße-Pfungstadt', 'LangweilerStraße-Aldenhoven',
#        'Vennweg-Schermbeck', 'Ellersdorf-Freudenberg',
#        'ImHeiligenBruch-Rheurdt', 'Gröbelweg-Osnabrück',
#        'Steinrutschweg-Köln', 'Tegelweg-Hannover', 'Nöckerstraße-Bochum',
#        'Willi-Graf-Straße-St.Ingbert', 'Graf-Edzard-Straße-Bunde',
#        'Hauptstraße-Rieschweiler-Mühlbach', 'Untergasse-Greifenstein',
#        'Mandlberg-Petting', 'Feldstraße-Brake',
#        'Laitschenbach-Münstertal', 'Thannhauserstraße-Freiburg',
#        'J.-Sebastian-Bach-Weg-Rodenberg', 'AlbersweilerStraße-Neuenhagen',
#        'Hintergasse-Fischbach', 'FünfkirchnerStraße-Darmstadt',
#        'Untertorstraße-Eschborn', 'Florian-Geyer-Straße-Bergtheim',
#        'Kirchstraße-Wiesweiler', 'Herrenstraße-Schöningen',
#        'FrillendorferStraße-Essen', 'AmHammer-Altenbeken',
#        'Römerstraße-Enkenbach-Alsenborn', 'Hans-Sachs-Straße-Duisburg',
#        'Bahnhofstraße-Salzhemmendorf', 'Schützenweg-Blomberg',
#        'Klostergasse-Saalfeld', 'Bergfeld-Rödental',
#        'Mittelstraße-Duisburg', 'Dorfstraße-Rheinsberg',
#        'Rönnelstraße-Brake', 'Ettigweg-Pößneck', 'Dehmke-Aerzen',
#        'Nagelschmiedstraße-Eschweiler', 'ZumSee-Ratekau',
#        'Flurstraße-Hamburg', 'ReichenbergerStraße-Regensburg',
#        'Haagstraße-Erftstadt', 'BrüsselerStraße-Euskirchen',
#        'FrankfurterStraße-Bebra', 'ZurWeiherwiese-Raumbach',
#        'Vennstraße-Stolberg', 'DickeHecke-Stolberg',
#        'Hauptstraße-Spiesen-Elversberg', 'ImSteinkamp-Edemissen',
#        'AmWackenstein-Ruppertsweiler', 'Hauptstraße-Prinzhöfte',
#        'Hirschbergstraße-Lenting', 'ImBrühl-Wendelsheim',
#        'Sandhofstraße-Enkenbach-Alsenborn', 'SchweinfurterStraße-Maßbach',
#        'Feldstraße-Lübz', 'Schützenweg-Alfeld', 'Amselweg-Wesseling',
#        'Osseweg-Leer', 'Ringstraße-Schwedelbach', 'Grube-Münnerstadt',
#        'Hauptstraße-Harzgerode', 'EndorferStraße-Ermsleben',
#        'Mühlbachstraße-Kronach', 'Osterende-Helvesiek',
#        'AlteDorfstraße-Zschepplin', 'Waldstraße-Frohburg',
#        'Schüfflerheide-Gelsenkirchen', 'GräfenhäuserStraße-Erzhausen',
#        'Hirschfeld-Hirschfeld', 'Vierruthenweg-Radebeul',
#        'Hauptstraße-Twieflingen', 'Boskoopstraße-Frankfurt',
#        '-Hallschlag', 'Siedlerstraße-Auerbach', '-Zweifelscheid',
#        'Heimbergstraße-Polle', '-Nusbaum', '-Ockfen', '-Watzerath',
#        'Schulstraße-Wiesbach', '-Dasburg', '-Malborn', '-Preischeid',
#        '-Wallendorf', 'EichelscheiderStraße-Bechhofen', '-Dockweiler',
#        '-Spiesen-Elversberg', 'AmHorberg-Rodalben',
#        'Wilhelm-Burkard-Straße-Forchheim', '-Röhl', '-Landscheid',
#        'MaichingerStraße-Böblingen', 'Einruhrstraße-Mönchengladbach',
#        '-Salmtal', 'Lothringerstr.100-Rehlingen-Siersburg',
#        'Waidmannweg-Mönchengladbach', '-Maring-Noviand',
#        'BlankenseerAllee-Trebbin', '-Üttfeld', '-Meckel'], dtype=object)

# %%
# removing streets name from location
df['location'] = df['location'].apply(lambda x: x.split('-')[-1])

# %%
df.head()
# Out:
#   sales_price livable_surface      land  number_of_rooms     location
# 0    548,000€           123m²     894m²                3  Merzkirchen
# 1     64,000€            76m²     612m²                4    Salzwedel
# 2    485,000€           180m²  71,600m²                6    Gusterath
# 3     47,000€            96m²     117m²                4   Heusweiler
# 4    595,000€           389m²   1,230m²               15         Zerf

# %%
# first location is the most frequently-occurring location. 
df['location'].value_counts()
# Out:
# Wadern         22
# Saarbrücken    21
# Trier          16
# Perl           12
# Losheim        10
#                ..
# Noviand         1
# Frielendorf     1
# Heemsen         1
# Mühlhausen      1
# Altenbeken      1
# Name: location, Length: 685, dtype: int64

# %% [markdown]
# ## Drop features that are not required to build our model

# %%
# we will work also with location to show how to handle categorical data
df_draft = df.drop(['location'],axis='columns')
df_draft.shape
# Out:
# (1116, 4)

# %% [markdown]
# ## Handle missing data if its NaN.

# %%
'''
We have no NaN values but something like: sales_price: Priceonrequest
'''
df = df.dropna()
df.isnull().sum()
# Out:
# sales_price        0
# livable_surface    0
# land               0
# number_of_rooms    0
# location           0
# dtype: int64

# %%
index_sales_price = df.columns.get_loc('sales_price')
price_pattern = r'([0-9]*(,|.)?[0-9]*(,|.)?[0-9]*\€)'

for row in range(0, len(df)-1):
    try:
        price = re.search(price_pattern, df.iat[row, index_sales_price]).group()
    except Exception as e:
        # drops sales_prices values which does not contains numerical value e.g. Priceonrequest
        df = df.drop(df.index[[row]])
    price = 'None'

# %%
df.head()
# Out:
#   sales_price livable_surface      land  number_of_rooms     location
# 0    548,000€           123m²     894m²                3  Merzkirchen
# 1     64,000€            76m²     612m²                4    Salzwedel
# 2    485,000€           180m²  71,600m²                6    Gusterath
# 3     47,000€            96m²     117m²                4   Heusweiler
# 4    595,000€           389m²   1,230m²               15         Zerf

# %%
# remove € sign and ',' from entire sales_prices...
df['sales_price'] = df['sales_price'].replace({r'\€':''}, regex = True)
df['sales_price'] = df['sales_price'].replace({r',':'.'}, regex = True)
df['livable_surface'] = df['livable_surface'].replace({r'm\u00b2':''}, regex = True)
df['land'] = df['land'].replace({r'm\u00b2':''}, regex = True)
df.rename(columns={'sales_price': 'sales_price', 'livable_surface': 'livable_surface_in_m\u00b2','land':'land_in_m\u00b2', 'number_of_rooms': 'number_of_rooms', 'location':'location'}, inplace=True)

# %%
df.head()
# Out:
#   sales_price livable_surface_in_m² land_in_m²  number_of_rooms     location
# 0     548.000                   123        894                3  Merzkirchen
# 1      64.000                    76        612                4    Salzwedel
# 2     485.000                   180     71,600                6    Gusterath
# 3      47.000                    96        117                4   Heusweiler
# 4     595.000                   389      1,230               15         Zerf

# %%
# store dataframe into csv
df.to_csv (f'{path}export_dataframe.csv',index = False, header=True)
